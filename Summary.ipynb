# %% [markdown]
# Time series provide the opportunity to forecast future values. Based on previous values, time series can be used to forecast trends in economics, weather, and capacity planning.
#
# In this project we build three seprate time series analysis over the dataset and give predictions for the next 4 years
#
# Gold Investment:- As we forecast further out into the future, it is natural for us to become less confident in our values. This is reflected by the intervals generated by our model, which show a up and down as we move further out into the future.
#
# Oil investment:- It initially show some variation but as we move further out into the future, it seem to be constant.
#
# Other invetment:- It does not show any proper variation.Forecast reflect constant variation as we move further out into future.
#
# While building model on all three investment gold,oil and otherInvestment,I will select Oil investment will be good investment because oil is used on daily basis.It is not trending or Seasonal, which mean oil will be in business for whole year.
